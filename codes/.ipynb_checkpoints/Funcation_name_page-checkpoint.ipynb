# %%
import numpy as np
import pandas as pd

# %%
def convert_to_HTML_format(function_names, webpage_name):
    html_string = '''
    <html>
        <head>
            <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.1/css/bootstrap.min.css">
            <style>body{ margin:0 100; background:whitesmoke; }</style>
        </head>
        <body>
            <h1>Function names</h1>

            <!-- *** Function Lists *** --->
            ''' + function_names + '''
        </body>
    </html>'''

    open_path = f'../webpages/{webpage_name}.html' # put a variable within a string
    f = open(open_path,'w')
    f.write(html_string)
    f.close()

# %%
function_name_df = pd.read_csv("../functions_data/High_AUC_PPV_FUNCTIONS.txt", sep="\t")
function_name_df
# Out:
#                                               GO_LABEL   tAUC    tF1  \
# 0                                  GO0005730_nucleolus  0.839  0.671
# 1                       GO0031012_extracellular_matrix  0.817  0.672
# 2           GO0030312_external_encapsulating_structure  0.824  0.662
# 3                            GO0042393_histone_binding  0.829  0.636
# 4                          GO0003682_chromatin_binding  0.836  0.623
# ..                                                 ...    ...    ...
# 143           GO0090304_nucleic_acid_metabolic_process  0.706  0.486
# 144             GO0030659_cytoplasmic_vesicle_membrane  0.713  0.489
# 145  GO0010562_positive_regulation_of_phosphorus_me...  0.701  0.484
# 146  GO0007167_enzyme_linked_receptor_protein_signa...  0.703  0.479
# 147  GO1903508_positive_regulation_of_nucleic_acid_...  0.707  0.470
#
#      tF1_NAIVE  tSPECIFICITY  tPRECISION(PPV)   tRECALL  tACCURACY  \
# 0        0.378      0.471061              1.8     0.872      0.630
# ...

# %%
function_names = function_name_df["GO_LABEL"].to_frame().to_html(index=False).replace('<table border="1" class="dataframe">','<table class="table table-striped">')
function_names
# Out:
# '<table class="table table-striped">\n  <thead>\n    <tr style="text-align: right;">\n      <th>GO_LABEL</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>GO0005730_nucleolus</td>\n    </tr>\n    <tr>\n      <td>GO0031012_extracellular_matrix</td>\n    </tr>\n    <tr>\n      <td>GO0030312_external_encapsulating_structure</td>\n    </tr>\n    <tr>\n      <td>GO0042393_histone_binding</td>\n    </tr>\n    <tr>\n      <td>GO0003682_chromatin_binding</td>\n    </tr>\n    <tr>\n      <td>GO0005911_cell_cell_junction</td>\n    </tr>\n    <tr>\n      <td>GO0006397_mRNA_processing</td>\n    </tr>\n    <tr>\n      <td>GO0000377_RNA_splicing,_via_transesterification_reactions_with_bulged_adenosine_as_nucleophile</td>\n    </tr>\n    <tr>\n      <td>GO0070161_anchoring_junction</td>\n    </tr>\n    <tr>\n      <td>GO0048018_receptor_ligand_activity</td>\n    </tr>\n    <tr>\n      <td>GO0006281_DNA_repair</td>\n    </tr>\n    <tr>\n      <td>GO0005681_spliceosomal_complex</td>\n    </
# ...

# %%
webpage_name = "function_names"
convert_to_HTML_format(function_names, webpage_name)

# %%
# store all function name into a txt file for generating function_names webpages
# np.savetxt("../functions_data/function_names.txt", function_name_df["GO_LABEL"].values, fmt='%s')
# no need to create a new txt file, we can use the "High_AUC_PPV_FUNCTIONS.txt" file
